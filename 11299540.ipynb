# %% [markdown]
# ## Personal Information
# <hr>
# Name: BORTEY JAPHETH BORTIERH <br>
# I.D: 11299540 <br>
# Class: BIOMEDICAL ENGINEERING LV. 200
# <hr>

# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import numpy as np

# %%
wine=pd.read_csv("red_wine.csv")
wine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %% [markdown]
# ### Previewing The First 10 rows::
# <hr>

# %%
wine.head(10)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
# 5            7.4              0.66         0.00             1.8      0.075
# 6            7.9              0.60         0.06             1.6        NaN
# 7            7.3              0.65         0.00             1.2      0.065
# 8            7.8              0.58         0.02             2.0      0.073
# 9            7.5              0.50         0.36             6.1      0.071
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %% [markdown]
# ### Previewing the last 20 rows::
# <hr>

# %%
wine.tail(20)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1579            6.2             0.560         0.09             1.7      0.053
# 1580            7.4             0.350         0.33             2.4      0.068
# 1581            6.2             0.560         0.09             1.7      0.053
# 1582            6.1             0.715         0.10             2.6      0.053
# 1583            6.2             0.460         0.29             2.1      0.074
# 1584            6.7             0.320         0.44             2.4      0.061
# 1585            7.2             0.390         0.44             2.6      0.066
# 1586            7.5             0.310         0.41             2.4      0.065
# 1587            5.8             0.610         0.11             1.8      0.066
# 1588            7.2             0.660         0.33             2.5      0.068
# 1589            6.6             0.725         0.20             7.8      0.073
# ...

# %% [markdown]
# ### Displaying basic information on the dataset::
# <hr>

# %%
wine.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1598 non-null   float64
#  1   volatile acidity      1598 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1595 non-null   float64
#  5   free sulfur dioxide   1598 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1598 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1598 non-null   float64
# dtypes: float64(12)
# memory usage: 150.0 KB

# %% [markdown]
# ### Displaying a statistical description of the dataset::
# <hr>

# %%
wine.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1598.000000       1598.000000  1599.000000     1599.000000
# mean        8.318335          0.527747     0.270976        2.538806
# std         1.740863          0.179092     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1595.000000          1598.000000           1599.000000  1598.000000
# mean      0.087476            15.867334             46.467792     0.996746
# std       0.047117            10.459029             32.895324     0.001887
# ...

# %% [markdown]
# ### Cleaning Data::
# <hr>

# %%
wine.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4        True
#         ...
# 1594    False
# 1595    False
# 1596     True
# 1597    False
# 1598    False
# Length: 1599, dtype: bool

# %%
wine.drop_duplicates( inplace=True)
wine.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1360 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1359 non-null   float64
#  1   volatile acidity      1359 non-null   float64
#  2   citric acid           1360 non-null   float64
#  3   residual sugar        1360 non-null   float64
#  4   chlorides             1356 non-null   float64
#  5   free sulfur dioxide   1359 non-null   float64
#  6   total sulfur dioxide  1360 non-null   float64
#  7   density               1359 non-null   float64
#  8   pH                    1360 non-null   float64
#  9   sulphates             1360 non-null   float64
#  10  alcohol               1360 non-null   float64
#  11  quality               1359 non-null   float64
# dtypes: float64(12)
# memory usage: 138.1 KB

# %%
column_list= list(wine.columns)
for column in column_list:
    if pd.api.types.is_numeric_dtype(wine[column]):
        decimal_places = wine[column].apply(lambda x: len(str(x).split('.')[1]) if '.' in str(x) else 0).max()
        c_mean=wine[column].mean()
        c_mean=round(c_mean,decimal_places)
        wine[column].fillna(c_mean ,inplace= True )
wine.info()
wine
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1360 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1360 non-null   float64
#  1   volatile acidity      1360 non-null   float64
#  2   citric acid           1360 non-null   float64
#  3   residual sugar        1360 non-null   float64
#  4   chlorides             1360 non-null   float64
#  5   free sulfur dioxide   1360 non-null   float64
#  6   total sulfur dioxide  1360 non-null   float64
#  7   density               1360 non-null   float64
#  8   pH                    1360 non-null   float64
#  9   sulphates             1360 non-null   float64
#  10  alcohol               1360 non-null   float64
#  11  quality               1360 non-null   float64
# dtypes: float64(12)
# memory usage: 138.1 KB
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# ...

# %%
wine.notnull().any()
# Out:
# fixed acidity           True
# volatile acidity        True
# citric acid             True
# residual sugar          True
# chlorides               True
# free sulfur dioxide     True
# total sulfur dioxide    True
# density                 True
# pH                      True
# sulphates               True
# alcohol                 True
# quality                 True
# dtype: bool

# %% [markdown]
# ### Visualizations--Analysis Using Graphs
# <hr>

# %% [markdown]
# #### 1. This is a scatter plot of fixed acidity against volatile acidity

# %%
plt.scatter(wine['fixed acidity'],wine['volatile acidity'],alpha=0.5,color= 'red',)
plt.title('Fixed Acidity vs. Volatile Acidity')
plt.xlabel('Fixed Acidity')
plt.ylabel('Volatile Acidity')
plt.grid(True)
plt.show()

# %% [markdown]
# <p>The graph above shows a visual representation of the fixed acidity of red wine against its volatile acidity properties.<br>
#     The correlation between the two properties is calculated below:
# </p>

# %%
correlation = wine['fixed acidity'].corr(wine['volatile acidity'])
f"Correlation between Fixed Acidity and Volatile Acidity: {correlation}"
# Out:
# 'Correlation between Fixed Acidity and Volatile Acidity: -0.2536702943445563'

# %% [markdown]
# <p>The correlation is -0.25 (in 2 decimal places).<br>This means that for a slight increase in the value of fixed acidity, there will be a decrease in the volatile acidity and vice versa</p>

# %% [markdown]
# #### 2. This is a pie chart to aid in analysing the quality of the red wine from the population of samples in the dataset

# %%
quality_counts=wine["quality"].value_counts()
quality_counts
# Out:
# quality
# 5.0    578
# 6.0    534
# 7.0    167
# 4.0     53
# 8.0     17
# 3.0     10
# 5.6      1
# Name: count, dtype: int64

# %%
plt.figure(figsize=(9, 9))
plt.pie(quality_counts, startangle=90)
plt.legend(quality_counts.index, title='Quality', loc='upper right')
plt.title('Distribution of Wine Quality')
plt.show()

# %%
x=list(quality_counts)
y=list()
for i in x:
    y.append(round(100*(i/1360),2))
    
y
# Out:
# [42.5, 39.26, 12.28, 3.9, 1.25, 0.74, 0.07]

# %% [markdown]
# <p>
#     The analysis of the 1360 samples in terms of percentages is given by the list 'y' above.
#     While the pie chart gives a visual representation.
#     It can be deduced from the chart and from 'y' that::</p>
#
#     - About 43% of the samples have a quality of 5.
#     - About 40% have a quality of 6.
#     - About 12% have a quality of 7.

# %% [markdown]
# #### 3. A histogram to show distibution of alchol content

# %%
plt.figure(figsize=(10, 6))
plt.hist(wine['alcohol'], bins=20, color='skyblue', edgecolor='black')

plt.title('Distribution of Alcohol Content')
plt.xlabel('Alcohol Content')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# <p>This histogram shows a distribution of the alcohol content in the red wine sample.<br>
#     Tt can be seen that majority of the red wine samples have alchol values ranging from 9-10
# </p>

# %% [markdown]
# ### 4. A correlation matrix is given below

# %%
wine.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.253670     0.666743
# volatile acidity          -0.253670          1.000000    -0.550044
# citric acid                0.666743         -0.550044     1.000000
# residual sugar             0.110854         -0.002315     0.143677
# chlorides                  0.085841          0.054840     0.209864
# free sulfur dioxide       -0.139697         -0.020594    -0.047980
# total sulfur dioxide      -0.102654          0.072330     0.047944
# density                    0.669663          0.024095     0.359303
# pH                        -0.685518          0.247134    -0.548681
# sulphates                  0.190179         -0.256906     0.325422
# alcohol                   -0.061209         -0.197716     0.104459
# quality                    0.119185         -0.395021     0.226886
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...
